# %%
pip install kagglehub
# Out:
# Looking in indexes: https://nexus.iisys.de/repository/ki-awz-pypi-group/simple, https://pypi.org/simple
# ...
#   Using cached kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# ...
# Using cached kagglehub-0.3.13-py3-none-any.whl (68 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ubitquitin/geolocation-geoguessr-images-50k")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/jovyan/.cache/kagglehub/datasets/ubitquitin/geolocation-geoguessr-images-50k/versions/1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sylshaw/streetview-by-country" )

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 7.39G/7.39G [03:55<00:00, 33.8MB/s]
# Extracting files...
# Path to dataset files: /home/jovyan/.cache/kagglehub/datasets/sylshaw/streetview-by-country/versions/2

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("paulchambaz/google-street-view" )

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.12/site-packages/kagglehub/exceptions.py:66, in kaggle_api_raise_for_status(response, resource_handle)
#      65 try:
# ---> 66     response.raise_for_status()
#      67 except requests.HTTPError as e:
#
# File /opt/conda/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/datasets/view/paulchambaz/google-street-viewy
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# Cell In[10], line 4
#       1 import kagglehub
#       3 # Download latest version
# ...

# %%
import shutil
#copy
src = "/home/jovyan/.cache/kagglehub/datasets/ubitquitin/geolocation-geoguessr-images-50k/versions/1"
dst = "DataMining/geoguessr_dataset"

shutil.copytree(src, dst, dirs_exist_ok=True)

print("Dataset copied to:", dst)
# Out:
# Dataset copied to: DataMining//geoguessr_dataset

# %%
import shutil
#move
src = "/home/jovyan/.cache/kagglehub/datasets/sylshaw/streetview-by-country/versions/2"
dst = "DataMining/streetviewByCountry"

shutil.move(src, dst)

print("Dataset moved to:", dst)
# Out:
# Dataset moved to: DataMining/streetviewByCountry

# %%
import shutil
#delete
cache_path = "/home/jovyan/.cache/kagglehub/datasets/ubitquitin/geolocation-geoguessr-images-50k"

shutil.rmtree(cache_path)

print("Deleted:", cache_path)
# Out:
# Deleted: /home/jovyan/.cache/kagglehub/datasets/ubitquitin/geolocation-geoguessr-images-50k

# %%
import shutil
#delete whole cache
cache_root = "/home/jovyan/.cache/kagglehub"

shutil.rmtree(cache_root)

print("Deleted:", cache_root)
# Out:
# Deleted: /home/jovyan/.cache/kagglehub

# %%
import os

data_path = "/home/jovyan/.cache/kagglehub/datasets/ubitquitin/geolocation-geoguessr-images-50k/versions/1"
data_path2= "/home/jovyan/.cache/kagglehub/datasets/sylshaw/streetview-by-country/versions/2"

for root, dirs, files in os.walk(data_path2):
    print(root, len(files))
    break
# Out:
# /home/jovyan/.cache/kagglehub/datasets/sylshaw/streetview-by-country/versions/2 0

# %%
import shutil
#delete
cache_path = "/home/jovyan/DataMining/streetviewByCountry"

shutil.rmtree(cache_path)

print("Deleted:", cache_path)
# Out:
# Deleted: /home/jovyan/DataMining/streetviewByCountry

# %%
pip install huggingface_hub
# Out:
# Looking in indexes: https://nexus.iisys.de/repository/ki-awz-pypi-group/simple, https://pypi.org/simple
# ...
#   Using cached huggingface_hub-1.1.4-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# ...
# Using cached huggingface_hub-1.1.4-py3-none-any.whl (515 kB)
# Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typer_slim-0.20.0-py3-none-any.whl (47 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [huggingface_hub] [huggingface_hub]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from huggingface_hub import snapshot_download

dataset_path = snapshot_download(
    repo_id="deboradum/GeoGuessr-countries",
    repo_type="dataset"     # ← important!
)

dataset_path
# Out:
# ...
# Fetching 25494 files:   0%|          | 0/25494 [00:00<?, ?it/s]
# '/home/jovyan/.cache/huggingface/hub/datasets--deboradum--GeoGuessr-countries/snapshots/2a6258e1e6cde675cdb7366ba125d8456baa78bf'

# %%
import shutil
#move
src = "/home/jovyan/.cache/huggingface/hub/datasets--deboradum--GeoGuessr-countries/"
dst = "DataMining/huggingFaceDataset"

shutil.move(src, dst)

print("Dataset moved to:", dst)
# Out:
# Dataset moved to: DataMining/huggingFaceDataset
